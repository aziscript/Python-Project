# %% [markdown]
# ![spreedsheet_finance](spreedsheet_finance.jpg)
#
# Your project is centered around developing a reinforcement learning (RL) simulation for stock trading in Python. This initiative is spearheaded by Quantum Trading, a fictional but ambitious trading firm looking to leverage cutting-edge machine learning techniques to gain a competitive edge in the financial markets. Quantum Trading is a small but highly specialised team of financial analysts, data scientists, and software engineers who are passionate about transforming the way trading decisions are made.
#
# In the fast-paced world of financial markets, staying ahead of the curve is crucial. Traditional trading strategies, while effective, often rely on historical data and predefined rules that may not adapt quickly to changing market conditions. Reinforcement learning, a subfield of machine learning where an agent learns to make decisions by interacting with an environment, offers a promising alternative. It allows the trading algorithms to learn and adapt in real-time, improving their performance as they gain more experience.
#
# By engaging with this project, you will gain valuable insights into the dynamic world of algorithmic trading and enhance your skill set in data science, finance, and machine learning. Remember, the journey of learning and experimentation is as important as the results. Good luck, and may your trading algorithms be ever profitable!
#
# ## The Data
# The provided data `AAPL.csv` contains historical prices for AAPL (the ticker symbol for Apple Inc) and you will be using this in your model. It has been loaded for you already in the sample code below and contains two columns, described below.
#
# | Column | Description |
# |--------|-------------|
# |`Date`    | The date corresponding to the closing price              |
# |`Close`   | The closing price of the security on the given date      |
#
# _**Disclaimer: This project is for educational purposes only. It is not financial advice, and should not be understood or construed as, financial advice.**_

# %% [markdown]
# # Proximal Policy Optimization (PPO) Trading Model Project
#
# Create and train a Proximal Policy Optimization (PPO) model using the provided environment. Train this model for a `total_timesteps` of **10,000**. Implement the trading logic to make buy, sell, or hold decisions based on the model's predictions.
#
# - Adjust the `cash balance` and `shares_held` based on the action taken (buy/sell) and allow the model to trade a certain percentage of its balance each step.
# - Monitor balance changes and store the history in `balance_history` for visualization.
# - If shares are still held at the end, sell them to update the final balance.
#
# By the end of this project you should have **two charts** that display the performance of the model:
#
# 1. **Chart 1**: Show the stock price with buy/sell actions overlaid on the price.
# 2. **Chart 2**: Show the cash balance over time.
#
# ---
#
# ## Questions:
#
# 1. **What do you think about the performance of this model?**
# 2. **Why do you think it has performed the way it has?**
# 3. **How could the data we have selected impact the performance of the model?**

# %%
# Make sure to run this cell to use gymnasium gym-anytrading stable-baselines3
# !pip install gymnasium gym-anytrading stable-baselines3
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Collecting gym-anytrading
#   Downloading gym_anytrading-2.0.0-py3-none-any.whl.metadata (292 bytes)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from gym-anytrading) (2.2.2)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from gym-anytrading) (3.10.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.6.0+cu124)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->gym-anytrading) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->gym-anytrading) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->gym-anytrading) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Downloading gym_anytrading-2.0.0-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 6.0 MB/s eta 0:00:00
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 20.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 40.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, gym-anytrading, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed gym-anytrading-2.0.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable-baselines3-2.6.0

# %%
# Import required packages
# Note that gym-anytrading is a gym environment specific for trading
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gymnasium as gym
import gym_anytrading
from gym_anytrading.envs import Actions
from stable_baselines3 import PPO

# Load the data provided
data = pd.read_csv("AAPL.csv", parse_dates=True, index_col='Date')

# Set window size (lookback window), start and end index of data
window_size = 10
start_index = window_size
end_index = len(data)

# Create the environment using the pre-built 'stocks-v0', passing in the data loaded above
# window_size is how far the environment can look back at each step
# frame_bound is the bounding box of the environment, the size of our data
env = gym.make('stocks-v0', df=data, window_size=window_size, frame_bound=(start_index, end_index))
print("Observation Space:", env.observation_space)

# Initialise cash balance tracking and other variables
balance = 100000
balance_history = [balance]
shares_held = 0
action_stats = {Actions.Sell: 0, Actions.Buy: 0}
observation, info = env.reset(seed=2024)
# Out:
# Observation Space: Box(-10000000000.0, 10000000000.0, (10, 2), float32)

# %%
# Train the PPO model
model = PPO('MlpPolicy', env, verbose=0)
model.learn(total_timesteps=10000)

step = 0
while True:
    action, _states = model.predict(observation)
    current_price = env.unwrapped.prices[env.unwrapped._current_tick]

    observation, reward, terminated, truncated, info = env.step(action)

    trade_amount = balance * 0.10  # Trade with 10% of current balance

    if action == Actions.Buy.value:
        shares_to_buy = trade_amount / current_price
        shares_held += shares_to_buy
        balance -= trade_amount
        print(f"{step}: BUY  {shares_to_buy:.2f} shares at ${current_price:.2f} | Balance: ${balance:.2f}")
    elif action == Actions.Sell.value and shares_held > 0:
        balance += shares_held * current_price
        print(f"{step}: SELL {shares_held:.2f} shares at ${current_price:.2f} | Balance: ${balance:.2f}")
        shares_held = 0
    else:
        print(f"{step}: HOLD | Current price: ${current_price:.2f} | Balance: ${balance:.2f}")

    action_stats[Actions(action)] += 1
    balance_history.append(balance)

    step += 1
    if terminated or truncated:
        break

# If we still hold shares at the end, sell them all
if shares_held > 0:
    balance += shares_held * current_price
    print(f"\nFinal SELL {shares_held:.2f} shares at ${current_price:.2f} | Balance: ${balance:.2f}")
    shares_held = 0

env.close()

print("Action stats:", action_stats)
print(f"Final Balance: ${balance:.2f}")
# Out:
# 0: BUY  134.43 shares at $74.39 | Balance: $90000.00
# 1: SELL 134.43 shares at $75.16 | Balance: $100103.17
# 2: HOLD | Current price: $75.93 | Balance: $100103.17
# 3: BUY  129.11 shares at $77.53 | Balance: $90092.85
# 4: SELL 129.11 shares at $78.75 | Balance: $100260.69
# 5: BUY  128.78 shares at $77.85 | Balance: $90234.62
# 6: BUY  117.32 shares at $76.91 | Balance: $81211.16
# 7: BUY  104.94 shares at $77.39 | Balance: $73090.04
# 8: BUY  95.01 shares at $76.93 | Balance: $65781.03
# 9: SELL 446.06 shares at $78.74 | Balance: $100903.79
# 10: HOLD | Current price: $78.29 | Balance: $100903.79
# 11: HOLD | Current price: $79.81 | Balance: $100903.79
# 12: HOLD | Current price: $79.21 | Balance: $100903.79
# 13: HOLD | Current price: $79.72 | Balance: $100903.79
# 14: BUY  127.43 shares at $79.18 | Balance: $90813.41
# 15: SELL 127.43 shares at $79.53 | Balance: $100947.75
# 16: HOLD | Current price: $79.56 | Balance: $100947.75
# 17: BUY  127.00 shares at $79.49 | Balance: $90852.98
# 18: SELL 127.00 shares at $80.46 | Balance: $101071.90
# 19: HOLD | Current price: $80.83 | Balance: $101071.90
# 20: HOLD | Current price: $81.28 | Balance: $101071.90
# 21: HOLD | Current price: $80.58 | Balance: $101071.90
# 22: HOLD | Current price: $82.88 | Balance: $101071.90
# 23: HOLD | Current price: $83.36 | Balance: $101071.90
# 24: BUY  117.53 shares at $86.00 | Balance: $90964.71
# 25: BUY  103.12 shares at $88.21 | Balance: $81868.24
# 26: BUY  97.49 shares at $83.97 | Balance: $73681.42
# 27: BUY  86.99 shares at $84.70 | Balance: $66313.28
# 28: BUY  77.34 shares at $85.75 | Balance: $59681.95
# 29: SELL 482.47 shares at $88.02 | Balance: $102148.92
# 30: BUY  116.21 shares at $87.90 | Balance: $91934.03
# 31: SELL 116.21 shares at $87.93 | Balance: $102152.99
# 32: BUY  116.84 shares at $87.43 | Balance: $91937.70
# 33: SELL 116.84 shares at $89.72 | Balance: $102420.27
# 34: BUY  111.77 shares at $91.63 | Balance: $92178.24
# 35: SELL 111.77 shares at $90.01 | Balance: $102239.48
# 36: HOLD | Current price: $91.21 | Balance: $102239.48
# 37: BUY  115.65 shares at $88.41 | Balance: $92015.53
# 38: SELL 115.65 shares at $90.44 | Balance: $102475.11
# 39: BUY  112.36 shares at $91.20 | Balance: $92227.60
# 40: SELL 112.36 shares at $91.03 | Balance: $102455.73
# 41: BUY  112.55 shares at $91.03 | Balance: $92210.16
# 42: SELL 112.55 shares at $93.46 | Balance: $102729.80
# 43: HOLD | Current price: $93.17 | Balance: $102729.80
# 44: HOLD | Current price: $95.34 | Balance: $102729.80
# 45: BUY  107.29 shares at $95.75 | Balance: $92456.82
# 46: SELL 107.29 shares at $95.92 | Balance: $102747.77
# 47: BUY  107.61 shares at $95.48 | Balance: $92472.99
# 48: BUY  95.28 shares at $97.06 | Balance: $83225.70
# 49: BUY  85.16 shares at $97.72 | Balance: $74903.12
# 50: BUY  77.60 shares at $96.52 | Balance: $67412.81
# 51: BUY  69.98 shares at $96.33 | Balance: $60671.53
# 52: BUY  61.68 shares at $98.36 | Balance: $54604.38
# 53: SELL 497.32 shares at $97.00 | Balance: $102844.77
# 54: HOLD | Current price: $97.27 | Balance: $102844.77
# 55: BUY  110.77 shares at $92.85 | Balance: $92560.30
# 56: SELL 110.77 shares at $92.61 | Balance: $102819.30
# 57: HOLD | Current price: $94.81 | Balance: $102819.30
# 58: HOLD | Current price: $93.25 | Balance: $102819.30
# 59: HOLD | Current price: $95.04 | Balance: $102819.30
# 60: HOLD | Current price: $96.19 | Balance: $102819.30
# 61: HOLD | Current price: $106.26 | Balance: $102819.30
# 62: HOLD | Current price: $108.94 | Balance: $102819.30
# 63: HOLD | Current price: $109.67 | Balance: $102819.30
# 64: HOLD | Current price: $110.06 | Balance: $102819.30
# 65: BUY  90.27 shares at $113.90 | Balance: $92537.37
# 66: SELL 90.27 shares at $111.11 | Balance: $102567.45
# 67: HOLD | Current price: $112.73 | Balance: $102567.45
# 68: BUY  93.78 shares at $109.38 | Balance: $92310.70
# 69: SELL 93.78 shares at $113.01 | Balance: $102908.33
# 70: HOLD | Current price: $115.01 | Balance: $102908.33
# 71: HOLD | Current price: $114.91 | Balance: $102908.33
# 72: HOLD | Current price: $114.61 | Balance: $102908.33
# 73: BUY  89.05 shares at $115.56 | Balance: $92617.49
# 74: SELL 89.05 shares at $115.71 | Balance: $102921.23
# 75: BUY  87.02 shares at $118.28 | Balance: $92629.11
# 76: SELL 87.02 shares at $124.37 | Balance: $103451.61
# 77: HOLD | Current price: $125.86 | Balance: $103451.61
# 78: BUY  82.88 shares at $124.82 | Balance: $93106.45
# 79: SELL 82.88 shares at $126.52 | Balance: $103592.29
# 80: BUY  82.87 shares at $125.01 | Balance: $93233.06
# 81: BUY  74.70 shares at $124.81 | Balance: $83909.76
# 82: SELL 157.57 shares at $129.04 | Balance: $104242.42
# 83: BUY  77.69 shares at $134.18 | Balance: $93818.18
# 84: SELL 77.69 shares at $131.40 | Balance: $104026.45
# 85: HOLD | Current price: $120.88 | Balance: $104026.45
# 86: HOLD | Current price: $120.96 | Balance: $104026.45
# 87: BUY  92.21 shares at $112.82 | Balance: $93623.80
# 88: BUY  79.80 shares at $117.32 | Balance: $84261.41
# 89: BUY  74.25 shares at $113.49 | Balance: $75835.27
# 90: SELL 246.25 shares at $112.00 | Balance: $103415.66
# 91: HOLD | Current price: $115.36 | Balance: $103415.66
# 92: BUY  89.51 shares at $115.54 | Balance: $93074.09
# 93: BUY  83.01 shares at $112.13 | Balance: $83766.69
# 94: BUY  75.92 shares at $110.34 | Balance: $75390.02
# 95: SELL 248.43 shares at $106.84 | Balance: $101932.14
# 96: BUY  92.60 shares at $110.08 | Balance: $91738.93
# 97: BUY  82.05 shares at $111.81 | Balance: $82565.04
# 98: SELL 174.65 shares at $107.12 | Balance: $101273.25
# 99: HOLD | Current price: $108.22 | Balance: $101273.25
# 100: BUY  90.20 shares at $112.28 | Balance: $91145.92
# 101: SELL 90.20 shares at $114.96 | Balance: $101514.98
# 102: HOLD | Current price: $114.09 | Balance: $101514.98
# 103: HOLD | Current price: $115.81 | Balance: $101514.98
# 104: HOLD | Current price: $116.79 | Balance: $101514.98
# 105: BUY  89.82 shares at $113.02 | Balance: $91363.48
# 106: BUY  78.42 shares at $116.50 | Balance: $82227.12
# 107: SELL 168.24 shares at $113.16 | Balance: $101265.61
# 108: BUY  88.00 shares at $115.08 | Balance: $91139.05
# 109: SELL 88.00 shares at $114.97 | Balance: $101255.93
# 110: BUY  86.57 shares at $116.97 | Balance: $91130.34
# 111: SELL 86.57 shares at $124.40 | Balance: $101899.11
# 112: BUY  84.14 shares at $121.10 | Balance: $91709.20
# 113: SELL 84.14 shares at $121.19 | Balance: $101906.68
# 114: HOLD | Current price: $120.71 | Balance: $101906.68
# 115: HOLD | Current price: $119.02 | Balance: $101906.68
# 116: BUY  87.87 shares at $115.98 | Balance: $91716.02
# 117: BUY  78.05 shares at $117.51 | Balance: $82544.41
# 118: SELL 165.92 shares at $116.87 | Balance: $101934.93
# 119: HOLD | Current price: $115.75 | Balance: $101934.93
# 120: BUY  88.61 shares at $115.04 | Balance: $91741.44
# 121: SELL 88.61 shares at $115.05 | Balance: $101935.82
# 122: HOLD | Current price: $116.60 | Balance: $101935.82
# 123: HOLD | Current price: $111.20 | Balance: $101935.82
# 124: BUY  88.39 shares at $115.32 | Balance: $91742.23
# 125: BUY  84.28 shares at $108.86 | Balance: $82568.01
# 126: BUY  75.91 shares at $108.77 | Balance: $74311.20
# 127: SELL 248.58 shares at $110.44 | Balance: $101764.38
# 128: BUY  88.53 shares at $114.95 | Balance: $91587.94
# 129: BUY  76.95 shares at $119.03 | Balance: $82429.14
# 130: SELL 165.47 shares at $118.69 | Balance: $102069.31
# 131: HOLD | Current price: $116.32 | Balance: $102069.31
# 132: HOLD | Current price: $115.97 | Balance: $102069.31
# 133: HOLD | Current price: $119.49 | Balance: $102069.31
# 134: BUY  85.62 shares at $119.21 | Balance: $91862.38
# 135: SELL 85.62 shares at $119.26 | Balance: $102073.59
# 136: HOLD | Current price: $120.30 | Balance: $102073.59
# 137: HOLD | Current price: $119.39 | Balance: $102073.59
# 138: HOLD | Current price: $118.03 | Balance: $102073.59
# 139: HOLD | Current price: $118.64 | Balance: $102073.59
# 140: HOLD | Current price: $117.34 | Balance: $102073.59
# 141: BUY  89.66 shares at $113.85 | Balance: $91866.23
# 142: BUY  79.77 shares at $115.17 | Balance: $82679.61
# 143: SELL 169.42 shares at $116.03 | Balance: $102337.64
# 144: BUY  87.78 shares at $116.59 | Balance: $92103.88
# 145: SELL 87.78 shares at $119.05 | Balance: $102553.57
# 146: HOLD | Current price: $122.72 | Balance: $102553.57
# 147: BUY  83.32 shares at $123.08 | Balance: $92298.21
# 148: SELL 83.32 shares at $122.94 | Balance: $102541.91
# 149: HOLD | Current price: $122.25 | Balance: $102541.91
# 150: BUY  82.86 shares at $123.75 | Balance: $92287.72
# 151: BUY  74.20 shares at $124.38 | Balance: $83058.95
# 152: SELL 157.06 shares at $121.78 | Balance: $102185.75
# 153: HOLD | Current price: $123.24 | Balance: $102185.75
# 154: HOLD | Current price: $122.41 | Balance: $102185.75
# 155: BUY  83.91 shares at $121.78 | Balance: $91967.17
# 156: SELL 83.91 shares at $127.88 | Balance: $102697.60
# 157: HOLD | Current price: $127.81 | Balance: $102697.60
# 158: HOLD | Current price: $128.70 | Balance: $102697.60
# 159: BUY  81.08 shares at $126.66 | Balance: $92427.84
# 160: SELL 81.08 shares at $128.23 | Balance: $102824.90
# 161: HOLD | Current price: $131.88 | Balance: $102824.90
# 162: HOLD | Current price: $130.96 | Balance: $102824.90
# 163: HOLD | Current price: $131.97 | Balance: $102824.90
# 164: HOLD | Current price: $136.69 | Balance: $102824.90
# 165: HOLD | Current price: $134.87 | Balance: $102824.90
# 166: BUY  76.90 shares at $133.72 | Balance: $92542.41
# 167: SELL 76.90 shares at $132.69 | Balance: $102745.70
# 168: HOLD | Current price: $129.41 | Balance: $102745.70
# 169: HOLD | Current price: $131.01 | Balance: $102745.70
# 170: HOLD | Current price: $126.60 | Balance: $102745.70
# 171: BUY  78.48 shares at $130.92 | Balance: $92471.12
# 172: BUY  70.03 shares at $132.05 | Balance: $83224.02
# 173: BUY  64.52 shares at $128.98 | Balance: $74901.62
# 174: BUY  58.15 shares at $128.80 | Balance: $67411.45
# 175: SELL 271.19 shares at $130.89 | Balance: $102906.90
# 176: BUY  79.83 shares at $128.91 | Balance: $92616.21
# 177: SELL 79.83 shares at $127.14 | Balance: $102765.60
# 178: BUY  80.39 shares at $127.83 | Balance: $92489.04
# 179: BUY  70.05 shares at $132.03 | Balance: $83240.13
# 180: BUY  60.82 shares at $136.87 | Balance: $74916.12
# 181: SELL 211.26 shares at $139.07 | Balance: $104296.17
# 182: HOLD | Current price: $142.92 | Balance: $104296.17
# 183: BUY  72.85 shares at $143.16 | Balance: $93866.55
# 184: SELL 72.85 shares at $142.06 | Balance: $104216.03
# 185: BUY  76.02 shares at $137.09 | Balance: $93794.43
# 186: SELL 76.02 shares at $131.96 | Balance: $103826.05
# 187: BUY  77.40 shares at $134.14 | Balance: $93443.45
# 188: SELL 77.40 shares at $134.99 | Balance: $103891.84
# 189: HOLD | Current price: $133.94 | Balance: $103891.84
# 190: HOLD | Current price: $137.39 | Balance: $103891.84
# 191: HOLD | Current price: $136.76 | Balance: $103891.84
# 192: HOLD | Current price: $136.91 | Balance: $103891.84
# 193: BUY  76.39 shares at $136.01 | Balance: $93502.66
# 194: BUY  69.06 shares at $135.39 | Balance: $84152.39
# 195: BUY  62.28 shares at $135.13 | Balance: $75737.15
# 196: BUY  55.95 shares at $135.37 | Balance: $68163.44
# 197: BUY  51.18 shares at $133.19 | Balance: $61347.09
# 198: BUY  46.89 shares at $130.84 | Balance: $55212.38
# 199: BUY  42.57 shares at $129.71 | Balance: $49691.14
# 200: SELL 404.30 shares at $129.87 | Balance: $102197.75
# 201: HOLD | Current price: $126.00 | Balance: $102197.75
# 202: HOLD | Current price: $125.86 | Balance: $102197.75
# 203: BUY  81.53 shares at $125.35 | Balance: $91977.98
# 204: BUY  76.02 shares at $120.99 | Balance: $82780.18
# 205: BUY  68.27 shares at $121.26 | Balance: $74502.16
# 206: BUY  58.30 shares at $127.79 | Balance: $67051.95
# 207: SELL 284.12 shares at $125.12 | Balance: $102600.82
# 208: BUY  84.06 shares at $122.06 | Balance: $92340.73
# 209: SELL 84.06 shares at $120.13 | Balance: $102438.59
# 210: HOLD | Current price: $121.42 | Balance: $102438.59
# 211: BUY  88.04 shares at $116.36 | Balance: $92194.73
# 212: SELL 88.04 shares at $121.09 | Balance: $102854.99
# 213: HOLD | Current price: $119.98 | Balance: $102854.99
# 214: HOLD | Current price: $121.96 | Balance: $102854.99
# 215: HOLD | Current price: $121.03 | Balance: $102854.99
# 216: HOLD | Current price: $123.99 | Balance: $102854.99
# 217: HOLD | Current price: $125.57 | Balance: $102854.99
# 218: BUY  82.44 shares at $124.76 | Balance: $92569.49
# 219: SELL 82.44 shares at $120.53 | Balance: $102506.26
# 220: BUY  85.43 shares at $119.99 | Balance: $92255.63
# 221: BUY  74.77 shares at $123.39 | Balance: $83030.07
# 222: BUY  67.76 shares at $122.54 | Balance: $74727.06
# 223: BUY  62.23 shares at $120.09 | Balance: $67254.36
# 224: BUY  55.77 shares at $120.59 | Balance: $60528.92
# 225: BUY  49.94 shares at $121.21 | Balance: $54476.03
# 226: SELL 395.89 shares at $121.39 | Balance: $102532.91
# 227: HOLD | Current price: $119.90 | Balance: $102532.91
# 228: HOLD | Current price: $122.15 | Balance: $102532.91
# 229: HOLD | Current price: $123.00 | Balance: $102532.91
# 230: HOLD | Current price: $125.90 | Balance: $102532.91
# 231: BUY  81.24 shares at $126.21 | Balance: $92279.62
# 232: SELL 81.24 shares at $127.90 | Balance: $102670.20
# 233: HOLD | Current price: $130.36 | Balance: $102670.20
# 234: BUY  77.20 shares at $133.00 | Balance: $92403.18
# 235: BUY  70.41 shares at $131.24 | Balance: $83162.86
# 236: SELL 147.60 shares at $134.43 | Balance: $103005.19
# 237: BUY  78.02 shares at $132.03 | Balance: $92704.67
# 238: BUY  68.93 shares at $134.50 | Balance: $83434.20
# 239: SELL 146.94 shares at $134.16 | Balance: $103147.93
# 240: BUY  76.50 shares at $134.84 | Balance: $92833.14
# 241: BUY  69.74 shares at $133.11 | Balance: $83549.83
# 242: SELL 146.24 shares at $133.50 | Balance: $103072.63
# 243: HOLD | Current price: $131.94 | Balance: $103072.63
# 244: HOLD | Current price: $134.32 | Balance: $103072.63
# 245: BUY  76.51 shares at $134.72 | Balance: $92765.37
# 246: BUY  69.03 shares at $134.39 | Balance: $83488.83
# 247: BUY  62.50 shares at $133.58 | Balance: $75139.95
# 248: SELL 208.04 shares at $133.48 | Balance: $102908.70
# 249: BUY  78.28 shares at $131.46 | Balance: $92617.83
# 250: SELL 78.28 shares at $132.54 | Balance: $102993.24
# 251: BUY  80.56 shares at $127.85 | Balance: $92693.92
# 252: SELL 80.56 shares at $128.10 | Balance: $103013.39
# 253: BUY  79.40 shares at $129.74 | Balance: $92712.05
# 254: BUY  71.20 shares at $130.21 | Balance: $83440.85
# 255: SELL 150.60 shares at $126.85 | Balance: $102544.69
# 256: HOLD | Current price: $125.91 | Balance: $102544.69
# 257: HOLD | Current price: $122.77 | Balance: $102544.69
# 258: HOLD | Current price: $124.97 | Balance: $102544.69
# 259: HOLD | Current price: $127.45 | Balance: $102544.69
# 260: HOLD | Current price: $126.27 | Balance: $102544.69
# 261: HOLD | Current price: $124.85 | Balance: $102544.69
# 262: HOLD | Current price: $124.69 | Balance: $102544.69
# 263: HOLD | Current price: $127.31 | Balance: $102544.69
# 264: HOLD | Current price: $125.43 | Balance: $102544.69
# 265: HOLD | Current price: $127.10 | Balance: $102544.69
# 266: BUY  80.81 shares at $126.90 | Balance: $92290.22
# 267: SELL 80.81 shares at $126.85 | Balance: $102540.65
# 268: BUY  81.85 shares at $125.28 | Balance: $92286.59
# 269: SELL 81.85 shares at $124.61 | Balance: $102485.81
# 270: HOLD | Current price: $124.28 | Balance: $102485.81
# 271: HOLD | Current price: $125.06 | Balance: $102485.81
# 272: BUY  82.96 shares at $123.54 | Balance: $92237.23
# 273: BUY  73.27 shares at $125.89 | Balance: $83013.51
# 274: SELL 156.23 shares at $125.90 | Balance: $102682.33
# 275: HOLD | Current price: $126.74 | Balance: $102682.33
# 276: HOLD | Current price: $127.13 | Balance: $102682.33
# 277: HOLD | Current price: $126.11 | Balance: $102682.33
# 278: HOLD | Current price: $127.35 | Balance: $102682.33
# 279: HOLD | Current price: $130.48 | Balance: $102682.33
# 280: HOLD | Current price: $129.64 | Balance: $102682.33
# 281: HOLD | Current price: $130.15 | Balance: $102682.33
# 282: HOLD | Current price: $131.79 | Balance: $102682.33
# 283: BUY  78.71 shares at $130.46 | Balance: $92414.09
# 284: BUY  69.85 shares at $132.30 | Balance: $83172.69
# 285: BUY  62.08 shares at $133.98 | Balance: $74855.42
# 286: SELL 210.64 shares at $133.70 | Balance: $103017.75
# 287: BUY  77.22 shares at $133.41 | Balance: $92715.98
# 288: SELL 77.22 shares at $133.11 | Balance: $102994.59
# 289: HOLD | Current price: $134.78 | Balance: $102994.59
# 290: HOLD | Current price: $136.33 | Balance: $102994.59
# 291: HOLD | Current price: $136.96 | Balance: $102994.59
# 292: HOLD | Current price: $137.27 | Balance: $102994.59
# 293: HOLD | Current price: $139.96 | Balance: $102994.59
# 294: BUY  72.52 shares at $142.02 | Balance: $92695.12
# 295: BUY  64.12 shares at $144.57 | Balance: $83425.61
# 296: BUY  58.24 shares at $143.24 | Balance: $75083.05
# 297: SELL 194.88 shares at $145.11 | Balance: $103362.20
# 298: HOLD | Current price: $144.50 | Balance: $103362.20
# 299: BUY  70.97 shares at $145.64 | Balance: $93025.98
# 300: SELL 70.97 shares at $149.15 | Balance: $103611.31
# 301: HOLD | Current price: $148.48 | Balance: $103611.31
# 302: HOLD | Current price: $146.39 | Balance: $103611.31
# 303: BUY  72.74 shares at $142.45 | Balance: $93250.18
# 304: SELL 72.74 shares at $146.15 | Balance: $103880.43
# 305: HOLD | Current price: $145.40 | Balance: $103880.43
# 306: BUY  70.76 shares at $146.80 | Balance: $93492.39
# 307: BUY  62.93 shares at $148.56 | Balance: $84143.15
# 308: SELL 133.70 shares at $148.99 | Balance: $104062.46
# 309: HOLD | Current price: $146.77 | Balance: $104062.46
# 310: HOLD | Current price: $144.98 | Balance: $104062.46
# 311: BUY  71.45 shares at $145.64 | Balance: $93656.22
# 312: BUY  64.21 shares at $145.86 | Balance: $84290.59
# 313: SELL 135.66 shares at $145.52 | Balance: $104032.05
# 314: BUY  70.60 shares at $147.36 | Balance: $93628.85
# 315: SELL 70.60 shares at $146.95 | Balance: $104003.11
# 316: HOLD | Current price: $147.06 | Balance: $104003.11
# 317: HOLD | Current price: $146.14 | Balance: $104003.11
# 318: BUY  71.19 shares at $146.09 | Balance: $93602.80
# 319: SELL 71.19 shares at $145.60 | Balance: $103968.23
# 320: HOLD | Current price: $145.86 | Balance: $103968.23
# 321: BUY  69.83 shares at $148.89 | Balance: $93571.41
# 322: SELL 69.83 shares at $149.10 | Balance: $103982.89
# 323: HOLD | Current price: $151.12 | Balance: $103982.89
# 324: HOLD | Current price: $150.19 | Balance: $103982.89
# 325: HOLD | Current price: $146.36 | Balance: $103982.89
# 326: HOLD | Current price: $146.70 | Balance: $103982.89
# 327: HOLD | Current price: $148.19 | Balance: $103982.89
# 328: HOLD | Current price: $149.71 | Balance: $103982.89
# 329: BUY  69.50 shares at $149.62 | Balance: $93584.60
# 330: BUY  63.08 shares at $148.36 | Balance: $84226.14
# 331: BUY  57.09 shares at $147.54 | Balance: $75803.52
# 332: SELL 189.66 shares at $148.60 | Balance: $103987.66
# 333: HOLD | Current price: $153.12 | Balance: $103987.66
# 334: HOLD | Current price: $151.83 | Balance: $103987.66
# 335: BUY  68.18 shares at $152.51 | Balance: $93588.89
# 336: SELL 68.18 shares at $153.65 | Balance: $104065.38
# 337: BUY  67.44 shares at $154.30 | Balance: $93658.84
# 338: BUY  59.77 shares at $156.69 | Balance: $84292.96
# 339: BUY  54.34 shares at $155.11 | Balance: $75863.66
# 340: BUY  49.24 shares at $154.07 | Balance: $68277.30
# 341: SELL 230.80 shares at $148.97 | Balance: $102659.66
# 342: HOLD | Current price: $149.55 | Balance: $102659.66
# 343: HOLD | Current price: $148.12 | Balance: $102659.66
# 344: BUY  68.89 shares at $149.03 | Balance: $92393.70
# 345: BUY  62.10 shares at $148.79 | Balance: $83154.33
# 346: SELL 130.98 shares at $146.06 | Balance: $102285.55
# 347: BUY  71.56 shares at $142.94 | Balance: $92057.00
# 348: BUY  64.18 shares at $143.43 | Balance: $82851.30
# 349: BUY  56.81 shares at $145.85 | Balance: $74566.16
# 350: SELL 192.55 shares at $146.83 | Balance: $102837.80
# 351: BUY  70.00 shares at $146.92 | Balance: $92554.02
# 352: BUY  63.67 shares at $145.37 | Balance: $83298.62
# 353: SELL 133.66 shares at $141.91 | Balance: $102266.84
# 354: BUY  71.60 shares at $142.83 | Balance: $92040.16
# 355: SELL 71.60 shares at $141.50 | Balance: $102171.61
# 356: BUY  71.62 shares at $142.65 | Balance: $91954.45
# 357: BUY  66.09 shares at $139.14 | Balance: $82759.00
# 358: SELL 137.71 shares at $141.11 | Balance: $102191.50
# 359: HOLD | Current price: $142.00 | Balance: $102191.50
# 360: BUY  71.32 shares at $143.29 | Balance: $91972.35
# 361: SELL 71.32 shares at $142.90 | Balance: $102163.69
# 362: HOLD | Current price: $142.81 | Balance: $102163.69
# 363: HOLD | Current price: $141.51 | Balance: $102163.69
# 364: HOLD | Current price: $140.91 | Balance: $102163.69
# 365: HOLD | Current price: $143.76 | Balance: $102163.69
# 366: HOLD | Current price: $144.84 | Balance: $102163.69
# 367: HOLD | Current price: $146.55 | Balance: $102163.69
# 368: BUY  68.68 shares at $148.76 | Balance: $91947.32
# 369: BUY  61.60 shares at $149.26 | Balance: $82752.59
# 370: SELL 130.28 shares at $149.48 | Balance: $102226.69
# 371: HOLD | Current price: $148.69 | Balance: $102226.69
# 372: HOLD | Current price: $148.64 | Balance: $102226.69
# 373: BUY  68.46 shares at $149.32 | Balance: $92004.02
# 374: SELL 68.46 shares at $148.85 | Balance: $102194.51
# 375: HOLD | Current price: $152.57 | Balance: $102194.51
# 376: BUY  68.22 shares at $149.80 | Balance: $91975.05
# 377: BUY  61.74 shares at $148.96 | Balance: $82777.55
# 378: BUY  55.18 shares at $150.02 | Balance: $74499.79
# 379: BUY  49.18 shares at $151.49 | Balance: $67049.81
# 380: BUY  44.42 shares at $150.96 | Balance: $60344.83
# 381: BUY  39.89 shares at $151.28 | Balance: $54310.35
# 382: BUY  36.10 shares at $150.44 | Balance: $48879.31
# 383: BUY  32.41 shares at $150.81 | Balance: $43991.38
# 384: SELL 387.14 shares at $147.92 | Balance: $101256.91
# 385: HOLD | Current price: $147.87 | Balance: $101256.91
# 386: BUY  67.51 shares at $149.99 | Balance: $91131.22
# 387: SELL 67.51 shares at $150.00 | Balance: $101257.59
# 388: HOLD | Current price: $151.00 | Balance: $101257.59
# 389: BUY  65.97 shares at $153.49 | Balance: $91131.83
# 390: SELL 65.97 shares at $157.87 | Balance: $101546.54
# 391: HOLD | Current price: $160.55 | Balance: $101546.54
# 392: HOLD | Current price: $161.02 | Balance: $101546.54
# 393: HOLD | Current price: $161.41 | Balance: $101546.54
# 394: BUY  62.71 shares at $161.94 | Balance: $91391.88
# 395: SELL 62.71 shares at $156.81 | Balance: $101224.85
# 396: HOLD | Current price: $160.24 | Balance: $101224.85
# 397: BUY  61.24 shares at $165.30 | Balance: $91102.37
# 398: BUY  55.29 shares at $164.77 | Balance: $81992.13
# 399: SELL 116.53 shares at $163.76 | Balance: $101074.70
# 400: BUY  62.45 shares at $161.84 | Balance: $90967.23
# 401: BUY  55.02 shares at $165.32 | Balance: $81870.51
# 402: SELL 117.48 shares at $171.18 | Balance: $101980.46
# 403: HOLD | Current price: $175.08 | Balance: $101980.46
# 404: HOLD | Current price: $174.56 | Balance: $101980.46
# 405: HOLD | Current price: $179.45 | Balance: $101980.46
# 406: HOLD | Current price: $175.74 | Balance: $101980.46
# 407: HOLD | Current price: $174.33 | Balance: $101980.46
# 408: HOLD | Current price: $179.30 | Balance: $101980.46
# 409: HOLD | Current price: $172.26 | Balance: $101980.46
# 410: HOLD | Current price: $171.14 | Balance: $101980.46
# 411: HOLD | Current price: $169.75 | Balance: $101980.46
# 412: HOLD | Current price: $172.99 | Balance: $101980.46
# 413: HOLD | Current price: $175.64 | Balance: $101980.46
# 414: HOLD | Current price: $176.28 | Balance: $101980.46
# 415: BUY  56.55 shares at $180.33 | Balance: $91782.41
# 416: SELL 56.55 shares at $179.29 | Balance: $101921.65
# 417: HOLD | Current price: $179.38 | Balance: $101921.65
# 418: HOLD | Current price: $178.20 | Balance: $101921.65
# 419: HOLD | Current price: $177.57 | Balance: $101921.65
# 420: HOLD | Current price: $182.01 | Balance: $101921.65
# 421: HOLD | Current price: $179.70 | Balance: $101921.65
# 422: HOLD | Current price: $174.92 | Balance: $101921.65
# 423: HOLD | Current price: $172.00 | Balance: $101921.65
# 424: BUY  59.20 shares at $172.17 | Balance: $91729.48
# 425: BUY  53.27 shares at $172.19 | Balance: $82556.54
# 426: SELL 112.47 shares at $175.08 | Balance: $102247.88
# 427: HOLD | Current price: $175.53 | Balance: $102247.88
# 428: BUY  59.38 shares at $172.19 | Balance: $92023.09
# 429: SELL 59.38 shares at $173.07 | Balance: $102300.13
# 430: BUY  60.25 shares at $169.80 | Balance: $92070.12
# 431: SELL 60.25 shares at $166.23 | Balance: $102085.05
# 432: HOLD | Current price: $164.51 | Balance: $102085.05
# 433: HOLD | Current price: $162.41 | Balance: $102085.05
# 434: HOLD | Current price: $161.62 | Balance: $102085.05
# 435: HOLD | Current price: $159.78 | Balance: $102085.05
# 436: HOLD | Current price: $159.69 | Balance: $102085.05
# 437: HOLD | Current price: $159.22 | Balance: $102085.05
# 438: HOLD | Current price: $170.33 | Balance: $102085.05
# 439: HOLD | Current price: $174.78 | Balance: $102085.05
# 440: BUY  58.46 shares at $174.61 | Balance: $91876.54
# 441: SELL 58.46 shares at $175.84 | Balance: $102156.95
# 442: BUY  59.08 shares at $172.90 | Balance: $91941.26
# 443: SELL 59.08 shares at $172.39 | Balance: $102126.82
# 444: HOLD | Current price: $171.66 | Balance: $102126.82
# 445: BUY  58.41 shares at $174.83 | Balance: $91914.14
# 446: BUY  52.14 shares at $176.28 | Balance: $82722.73
# 447: SELL 110.56 shares at $172.12 | Balance: $101751.61
# 448: BUY  60.34 shares at $168.64 | Balance: $91576.45
# 449: SELL 60.34 shares at $168.88 | Balance: $101766.09
# 450: BUY  58.90 shares at $172.79 | Balance: $91589.48
# 451: SELL 58.90 shares at $172.55 | Balance: $101751.95
# 452: HOLD | Current price: $168.88 | Balance: $101751.95
# 453: BUY  60.82 shares at $167.30 | Balance: $91576.76
# 454: SELL 60.82 shares at $164.32 | Balance: $101570.71
# 455: HOLD | Current price: $160.07 | Balance: $101570.71
# 456: HOLD | Current price: $162.74 | Balance: $101570.71
# 457: HOLD | Current price: $164.85 | Balance: $101570.71
# 458: BUY  61.51 shares at $165.12 | Balance: $91413.64
# 459: BUY  56.01 shares at $163.20 | Balance: $82272.27
# 460: SELL 117.53 shares at $166.56 | Balance: $101847.49
# 461: HOLD | Current price: $166.23 | Balance: $101847.49
# 462: BUY  62.42 shares at $163.17 | Balance: $91662.74
# 463: SELL 62.42 shares at $159.30 | Balance: $101605.94
# 464: BUY  64.54 shares at $157.44 | Balance: $91445.34
# 465: SELL 64.54 shares at $162.95 | Balance: $101961.53
# 466: HOLD | Current price: $158.52 | Balance: $101961.53
# 467: HOLD | Current price: $154.73 | Balance: $101961.53
# 468: HOLD | Current price: $150.62 | Balance: $101961.53
# 469: BUY  65.74 shares at $155.09 | Balance: $91765.38
# 470: SELL 65.74 shares at $159.59 | Balance: $102257.38
# 471: HOLD | Current price: $160.62 | Balance: $102257.38
# 472: HOLD | Current price: $163.98 | Balance: $102257.38
# 473: BUY  61.83 shares at $165.38 | Balance: $92031.64
# 474: SELL 61.83 shares at $168.82 | Balance: $102470.08
# 475: BUY  60.20 shares at $170.21 | Balance: $92223.07
# 476: BUY  52.98 shares at $174.07 | Balance: $83000.77
# 477: SELL 113.18 shares at $174.72 | Balance: $102776.03
# 478: BUY  58.53 shares at $175.60 | Balance: $92498.43
# 479: SELL 58.53 shares at $178.96 | Balance: $102972.69
# 480: BUY  57.92 shares at $177.77 | Balance: $92675.42
# 481: SELL 57.92 shares at $174.61 | Balance: $102789.65
# 482: HOLD | Current price: $174.31 | Balance: $102789.65
# 483: HOLD | Current price: $178.44 | Balance: $102789.65
# 484: BUY  58.72 shares at $175.06 | Balance: $92510.69
# 485: SELL 58.72 shares at $171.83 | Balance: $102600.00
# 486: HOLD | Current price: $172.14 | Balance: $102600.00
# 487: HOLD | Current price: $170.09 | Balance: $102600.00
# 488: BUY  61.90 shares at $165.75 | Balance: $92340.00
# 489: SELL 61.90 shares at $167.66 | Balance: $102718.23
# 490: HOLD | Current price: $170.40 | Balance: $102718.23
# 491: HOLD | Current price: $165.29 | Balance: $102718.23
# 492: HOLD | Current price: $165.07 | Balance: $102718.23
# 493: HOLD | Current price: $167.40 | Balance: $102718.23
# 494: HOLD | Current price: $167.23 | Balance: $102718.23
# 495: BUY  61.72 shares at $166.42 | Balance: $92446.41
# 496: SELL 61.72 shares at $161.79 | Balance: $102432.45
# 497: BUY  62.89 shares at $162.88 | Balance: $92189.21
# 498: SELL 62.89 shares at $156.80 | Balance: $102050.09
# 499: HOLD | Current price: $156.57 | Balance: $102050.09
# 500: HOLD | Current price: $163.64 | Balance: $102050.09
# 501: HOLD | Current price: $157.65 | Balance: $102050.09
# 502: HOLD | Current price: $157.96 | Balance: $102050.09
# 503: HOLD | Current price: $159.48 | Balance: $102050.09
# 504: BUY  61.47 shares at $166.02 | Balance: $91845.09
# 505: BUY  58.59 shares at $156.77 | Balance: $82660.58
# 506: BUY  52.56 shares at $157.28 | Balance: $74394.52
# 507: BUY  48.92 shares at $152.06 | Balance: $66955.07
# 508: BUY  43.33 shares at $154.51 | Balance: $60259.56
# 509: SELL 264.87 shares at $146.50 | Balance: $99062.88
# 510: BUY  69.49 shares at $142.56 | Balance: $89156.59
# 511: BUY  60.61 shares at $147.11 | Balance: $80240.93
# 512: BUY  55.13 shares at $145.54 | Balance: $72216.84
# 513: SELL 185.23 shares at $149.24 | Balance: $99860.14
# 514: HOLD | Current price: $140.82 | Balance: $99860.14
# 515: BUY  72.70 shares at $137.35 | Balance: $89874.12
# 516: SELL 72.70 shares at $137.59 | Balance: $99877.59
# 517: HOLD | Current price: $143.11 | Balance: $99877.59
# 518: BUY  71.16 shares at $140.36 | Balance: $89889.83
# 519: SELL 71.16 shares at $140.52 | Balance: $99888.97
# 520: BUY  69.47 shares at $143.78 | Balance: $89900.07
# 521: SELL 69.47 shares at $149.64 | Balance: $100296.09
# 522: HOLD | Current price: $148.84 | Balance: $100296.09
# 523: BUY  67.44 shares at $148.71 | Balance: $90266.48
# 524: BUY  59.70 shares at $151.21 | Balance: $81239.83
# 525: BUY  55.88 shares at $145.38 | Balance: $73115.84
# 526: SELL 183.02 shares at $146.14 | Balance: $99862.56
# 527: HOLD | Current price: $148.71 | Balance: $99862.56
# 528: HOLD | Current price: $147.96 | Balance: $99862.56
# 529: BUY  70.01 shares at $142.64 | Balance: $89876.30
# 530: SELL 70.01 shares at $137.13 | Balance: $99476.80
# 531: HOLD | Current price: $131.88 | Balance: $99476.80
# 532: HOLD | Current price: $132.76 | Balance: $99476.80
# 533: HOLD | Current price: $135.43 | Balance: $99476.80
# 534: BUY  76.49 shares at $130.06 | Balance: $89529.12
# 535: SELL 76.49 shares at $131.56 | Balance: $99591.53
# 536: HOLD | Current price: $135.87 | Balance: $99591.53
# 537: HOLD | Current price: $135.35 | Balance: $99591.53
# 538: BUY  72.03 shares at $138.27 | Balance: $89632.38
# 539: SELL 72.03 shares at $141.66 | Balance: $99835.70
# 540: HOLD | Current price: $141.66 | Balance: $99835.70
# 541: BUY  72.64 shares at $137.44 | Balance: $89852.13
# 542: BUY  64.54 shares at $139.23 | Balance: $80866.92
# 543: BUY  59.15 shares at $136.72 | Balance: $72780.23
# 544: BUY  52.39 shares at $138.93 | Balance: $65502.20
# 545: SELL 248.71 shares at $141.56 | Balance: $100709.40
# 546: BUY  70.47 shares at $142.92 | Balance: $90638.46
# 547: BUY  61.93 shares at $146.35 | Balance: $81574.62
# 548: SELL 132.40 shares at $147.04 | Balance: $101042.45
# 549: HOLD | Current price: $144.87 | Balance: $101042.45
# 550: BUY  69.27 shares at $145.86 | Balance: $90938.21
# 551: SELL 69.27 shares at $145.49 | Balance: $101016.83
# 552: BUY  68.04 shares at $148.47 | Balance: $90915.15
# 553: SELL 68.04 shares at $150.17 | Balance: $101132.50
# 554: HOLD | Current price: $147.07 | Balance: $101132.50
# 555: BUY  66.98 shares at $151.00 | Balance: $91019.25
# 556: SELL 66.98 shares at $153.04 | Balance: $101269.12
# 557: BUY  65.19 shares at $155.35 | Balance: $91142.21
# 558: BUY  59.15 shares at $154.09 | Balance: $82027.99
# 559: SELL 124.34 shares at $152.95 | Balance: $101045.25
# 560: HOLD | Current price: $151.60 | Balance: $101045.25
# 561: BUY  64.45 shares at $156.79 | Balance: $90940.73
# 562: BUY  57.80 shares at $157.35 | Balance: $81846.66
# 563: BUY  50.36 shares at $162.51 | Balance: $73661.99
# 564: BUY  45.61 shares at $161.51 | Balance: $66295.80
# 565: BUY  41.43 shares at $160.01 | Balance: $59666.22
# 566: BUY  35.92 shares at $166.13 | Balance: $53699.60
# 567: BUY  32.39 shares at $165.81 | Balance: $48329.64
# 568: SELL 327.95 shares at $165.35 | Balance: $102555.80
# 569: HOLD | Current price: $164.87 | Balance: $102555.80
# 570: HOLD | Current price: $164.92 | Balance: $102555.80
# 571: HOLD | Current price: $169.24 | Balance: $102555.80
# 572: BUY  60.87 shares at $168.49 | Balance: $92300.22
# 573: BUY  53.63 shares at $172.10 | Balance: $83070.20
# 574: BUY  47.96 shares at $173.19 | Balance: $74763.17
# 575: SELL 162.46 shares at $173.03 | Balance: $102874.34
# 576: BUY  58.94 shares at $174.55 | Balance: $92586.91
# 577: BUY  53.17 shares at $174.15 | Balance: $83328.22
# 578: SELL 112.10 shares at $171.52 | Balance: $102555.94
# 579: HOLD | Current price: $167.57 | Balance: $102555.94
# 580: HOLD | Current price: $167.23 | Balance: $102555.94
# 581: HOLD | Current price: $167.53 | Balance: $102555.94
# 582: HOLD | Current price: $170.03 | Balance: $102555.94
# 583: HOLD | Current price: $163.62 | Balance: $102555.94
# 584: BUY  63.55 shares at $161.38 | Balance: $92300.34
# 585: BUY  58.08 shares at $158.91 | Balance: $83070.31
# 586: BUY  52.84 shares at $157.22 | Balance: $74763.28
# 587: BUY  47.33 shares at $157.96 | Balance: $67286.95
# 588: SELL 221.80 shares at $155.81 | Balance: $101845.66
# 589: HOLD | Current price: $154.53 | Balance: $101845.66
# 590: HOLD | Current price: $155.96 | Balance: $101845.66
# 591: BUY  65.94 shares at $154.46 | Balance: $91661.09
# 592: SELL 65.94 shares at $157.37 | Balance: $102037.53
# 593: HOLD | Current price: $163.43 | Balance: $102037.53
# 594: HOLD | Current price: $153.84 | Balance: $102037.53
# 595: HOLD | Current price: $155.31 | Balance: $102037.53
# 596: HOLD | Current price: $152.37 | Balance: $102037.53
# 597: BUY  67.71 shares at $150.70 | Balance: $91833.78
# 598: BUY  59.45 shares at $154.48 | Balance: $82650.41
# 599: SELL 127.16 shares at $156.90 | Balance: $102601.20
# 600: HOLD | Current price: $153.72 | Balance: $102601.20
# 601: BUY  67.17 shares at $152.74 | Balance: $92341.08
# 602: SELL 67.17 shares at $150.43 | Balance: $102446.02
# 603: BUY  67.95 shares at $150.77 | Balance: $92201.42
# 604: BUY  60.75 shares at $151.76 | Balance: $82981.28
# 605: SELL 128.70 shares at $149.84 | Balance: $102266.19
# 606: HOLD | Current price: $142.48 | Balance: $102266.19
# 607: BUY  74.00 shares at $138.20 | Balance: $92039.57
# 608: SELL 74.00 shares at $142.45 | Balance: $102580.69
# 609: HOLD | Current price: $146.10 | Balance: $102580.69
# 610: HOLD | Current price: $146.40 | Balance: $102580.69
# 611: BUY  70.54 shares at $145.43 | Balance: $92322.62
# 612: BUY  65.90 shares at $140.09 | Balance: $83090.36
# 613: SELL 136.44 shares at $140.42 | Balance: $102249.05
# 614: BUY  73.57 shares at $138.98 | Balance: $92024.15
# 615: SELL 73.57 shares at $138.34 | Balance: $102201.97
# 616: BUY  71.47 shares at $142.99 | Balance: $91981.77
# 617: BUY  66.47 shares at $138.38 | Balance: $82783.59
# 618: SELL 137.95 shares at $142.41 | Balance: $102428.39
# 619: BUY  71.25 shares at $143.75 | Balance: $92185.55
# 620: SELL 71.25 shares at $143.86 | Balance: $102436.23
# 621: BUY  71.44 shares at $143.39 | Balance: $92192.61
# 622: BUY  62.60 shares at $147.27 | Balance: $82973.35
# 623: SELL 134.04 shares at $149.45 | Balance: $103005.62
# 624: BUY  67.62 shares at $152.34 | Balance: $92705.06
# 625: SELL 67.62 shares at $149.35 | Balance: $102803.45
# 626: HOLD | Current price: $144.80 | Balance: $102803.45
# 627: HOLD | Current price: $155.74 | Balance: $102803.45
# 628: BUY  67.04 shares at $153.34 | Balance: $92523.11
# 629: SELL 67.04 shares at $150.65 | Balance: $102623.11
# 630: HOLD | Current price: $145.03 | Balance: $102623.11
# 631: HOLD | Current price: $138.88 | Balance: $102623.11
# 632: HOLD | Current price: $138.38 | Balance: $102623.11
# 633: HOLD | Current price: $138.92 | Balance: $102623.11
# 634: BUY  73.56 shares at $139.50 | Balance: $92360.80
# 635: BUY  68.48 shares at $134.87 | Balance: $83124.72
# 636: SELL 142.05 shares at $146.87 | Balance: $103987.06
# 637: BUY  69.46 shares at $149.70 | Balance: $93588.36
# 638: SELL 69.46 shares at $148.28 | Balance: $103888.43
# 639: BUY  69.24 shares at $150.04 | Balance: $93499.59
# 640: BUY  62.84 shares at $148.79 | Balance: $84149.62
# 641: SELL 132.08 shares at $150.72 | Balance: $104056.80
# 642: HOLD | Current price: $151.29 | Balance: $104056.80
# 643: BUY  70.30 shares at $148.01 | Balance: $93651.12
# 644: BUY  62.36 shares at $150.18 | Balance: $84286.01
# 645: BUY  55.79 shares at $151.07 | Balance: $75857.41
# 646: SELL 188.46 shares at $148.11 | Balance: $103769.60
# 647: HOLD | Current price: $144.22 | Balance: $103769.60
# 648: HOLD | Current price: $141.17 | Balance: $103769.60
# 649: HOLD | Current price: $148.03 | Balance: $103769.60
# 650: HOLD | Current price: $148.31 | Balance: $103769.60
# 651: HOLD | Current price: $147.81 | Balance: $103769.60
# 652: HOLD | Current price: $146.63 | Balance: $103769.60
# 653: HOLD | Current price: $142.91 | Balance: $103769.60
# 654: HOLD | Current price: $140.94 | Balance: $103769.60
# 655: BUY  72.74 shares at $142.65 | Balance: $93392.64
# 656: SELL 72.74 shares at $142.16 | Balance: $103733.95
# 657: BUY  71.79 shares at $144.49 | Balance: $93360.55
# 658: SELL 71.79 shares at $145.47 | Balance: $103804.30
# 659: BUY  72.48 shares at $143.21 | Balance: $93423.88
# 660: BUY  68.44 shares at $136.50 | Balance: $84081.48
# 661: SELL 140.93 shares at $134.51 | Balance: $103037.49
# 662: BUY  77.84 shares at $132.37 | Balance: $92733.74
# 663: BUY  70.09 shares at $132.30 | Balance: $83460.37
# 664: BUY  61.62 shares at $135.45 | Balance: $75114.33
# 665: SELL 209.55 shares at $132.23 | Balance: $102823.28
# 666: HOLD | Current price: $131.86 | Balance: $102823.28
# 667: HOLD | Current price: $130.03 | Balance: $102823.28
# 668: BUY  81.58 shares at $126.04 | Balance: $92540.95
# 669: BUY  71.40 shares at $129.61 | Balance: $83286.86
# 670: BUY  64.10 shares at $129.93 | Balance: $74958.17
# 671: SELL 217.08 shares at $125.07 | Balance: $102108.47
# 672: BUY  80.81 shares at $126.36 | Balance: $91897.62
# 673: BUY  73.51 shares at $125.02 | Balance: $82707.86
# 674: SELL 154.31 shares at $129.62 | Balance: $102710.03
# 675: HOLD | Current price: $130.15 | Balance: $102710.03
# 676: HOLD | Current price: $130.73 | Balance: $102710.03
# 677: BUY  76.94 shares at $133.49 | Balance: $92439.03
# 678: BUY  69.29 shares at $133.41 | Balance: $83195.12
# 679: SELL 146.23 shares at $134.76 | Balance: $102901.28
# 680: HOLD | Current price: $135.94 | Balance: $102901.28
# 681: BUY  76.10 shares at $135.21 | Balance: $92611.16
# 682: BUY  68.46 shares at $135.27 | Balance: $83350.04
# 683: BUY  60.46 shares at $137.87 | Balance: $75015.03
# 684: SELL 205.02 shares at $141.11 | Balance: $103946.00
# 685: HOLD | Current price: $142.53 | Balance: $103946.00
# 686: HOLD | Current price: $141.86 | Balance: $103946.00
# 687: HOLD | Current price: $143.96 | Balance: $103946.00
# 688: BUY  71.23 shares at $145.93 | Balance: $93551.40
# 689: SELL 71.23 shares at $143.00 | Balance: $103737.30
# 690: HOLD | Current price: $144.29 | Balance: $103737.30
# 691: BUY  71.33 shares at $145.43 | Balance: $93363.57
# 692: SELL 71.33 shares at $150.82 | Balance: $104121.78
# 693: BUY  67.39 shares at $154.50 | Balance: $93709.60
# 694: SELL 67.39 shares at $151.73 | Balance: $103935.10
# 695: HOLD | Current price: $154.65 | Balance: $103935.10
# 696: BUY  68.41 shares at $151.92 | Balance: $93541.59
# 697: BUY  62.00 shares at $150.87 | Balance: $84187.44
# 698: BUY  55.75 shares at $151.01 | Balance: $75768.70
# 699: SELL 186.17 shares at $153.85 | Balance: $104410.24
# 700: HOLD | Current price: $153.20 | Balance: $104410.24
# 701: HOLD | Current price: $155.33 | Balance: $104410.24
# 702: HOLD | Current price: $153.71 | Balance: $104410.24
# 703: HOLD | Current price: $152.55 | Balance: $104410.24
# 704: HOLD | Current price: $148.48 | Balance: $104410.24
# 705: HOLD | Current price: $148.91 | Balance: $104410.24
# 706: BUY  69.89 shares at $149.40 | Balance: $93969.22
# 707: BUY  64.05 shares at $146.71 | Balance: $84572.30
# 708: SELL 133.94 shares at $147.92 | Balance: $104384.31
# 709: HOLD | Current price: $147.41 | Balance: $104384.31
# 710: HOLD | Current price: $145.31 | Balance: $104384.31
# 711: BUY  71.54 shares at $145.91 | Balance: $93945.88
# 712: SELL 71.54 shares at $151.03 | Balance: $104750.60
# 713: HOLD | Current price: $153.83 | Balance: $104750.60
# 714: HOLD | Current price: $151.60 | Balance: $104750.60
# 715: HOLD | Current price: $152.87 | Balance: $104750.60
# 716: BUY  69.56 shares at $150.59 | Balance: $94275.54
# 717: BUY  63.49 shares at $148.50 | Balance: $84847.98
# 718: SELL 133.05 shares at $150.47 | Balance: $104867.32
# 719: BUY  68.72 shares at $152.59 | Balance: $94380.59
# 720: SELL 68.72 shares at $152.99 | Balance: $104894.81
# 721: BUY  67.30 shares at $155.85 | Balance: $94405.33
# 722: SELL 67.30 shares at $155.00 | Balance: $104837.60
# 723: HOLD | Current price: $157.40 | Balance: $104837.60
# 724: BUY  65.82 shares at $159.28 | Balance: $94353.84
# 725: SELL 65.82 shares at $157.83 | Balance: $104742.16
# 726: BUY  65.90 shares at $158.93 | Balance: $94267.95
# 727: SELL 65.90 shares at $160.25 | Balance: $104829.16
# 728: HOLD | Current price: $158.28 | Balance: $104829.16
# 729: HOLD | Current price: $157.65 | Balance: $104829.16
# 730: HOLD | Current price: $160.77 | Balance: $104829.16
# 731: HOLD | Current price: $162.36 | Balance: $104829.16
# 732: HOLD | Current price: $164.90 | Balance: $104829.16
# 733: HOLD | Current price: $166.17 | Balance: $104829.16
# 734: BUY  63.29 shares at $165.63 | Balance: $94346.24
# 735: BUY  57.61 shares at $163.76 | Balance: $84911.62
# 736: BUY  51.57 shares at $164.66 | Balance: $76420.45
# 737: SELL 172.47 shares at $162.03 | Balance: $104366.02
# 738: HOLD | Current price: $160.80 | Balance: $104366.02
# 739: HOLD | Current price: $160.10 | Balance: $104366.02
# 740: BUY  63.04 shares at $165.56 | Balance: $93929.41
# 741: BUY  56.85 shares at $165.21 | Balance: $84536.47
# 742: SELL 119.89 shares at $165.23 | Balance: $104346.34
# 743: HOLD | Current price: $166.47 | Balance: $104346.34
# 744: BUY  62.25 shares at $167.63 | Balance: $93911.71
# 745: SELL 62.25 shares at $166.65 | Balance: $104285.34
# 746: HOLD | Current price: $165.02 | Balance: $104285.34
# 747: HOLD | Current price: $165.33 | Balance: $104285.34
# 748: HOLD | Current price: $163.77 | Balance: $104285.34
# 749: BUY  63.68 shares at $163.76 | Balance: $93856.81
# 750: BUY  55.73 shares at $168.41 | Balance: $84471.13
# 751: BUY  49.78 shares at $169.68 | Balance: $76024.02
# 752: SELL 169.20 shares at $169.59 | Balance: $104717.89
# 753: BUY  62.13 shares at $168.54 | Balance: $94246.10
# 754: SELL 62.13 shares at $167.45 | Balance: $104650.16
# 755: HOLD | Current price: $165.79 | Balance: $104650.16
# 756: BUY  60.29 shares at $173.57 | Balance: $94185.15
# 757: SELL 60.29 shares at $173.50 | Balance: $104645.95
# 758: HOLD | Current price: $171.77 | Balance: $104645.95
# 759: HOLD | Current price: $173.56 | Balance: $104645.95
# 760: HOLD | Current price: $173.75 | Balance: $104645.95
# 761: HOLD | Current price: $172.57 | Balance: $104645.95
# 762: HOLD | Current price: $172.07 | Balance: $104645.95
# 763: BUY  60.82 shares at $172.07 | Balance: $94181.35
# 764: SELL 60.82 shares at $172.69 | Balance: $104683.66
# 765: HOLD | Current price: $175.05 | Balance: $104683.66
# 766: BUY  59.76 shares at $175.16 | Balance: $94215.29
# 767: SELL 59.76 shares at $174.20 | Balance: $104626.28
# 768: HOLD | Current price: $171.56 | Balance: $104626.28
# 769: BUY  60.89 shares at $171.84 | Balance: $94163.66
# 770: SELL 60.89 shares at $172.99 | Balance: $104696.30
# 771: BUY  59.68 shares at $175.43 | Balance: $94226.67
# 772: BUY  53.15 shares at $177.30 | Balance: $84804.01
# 773: BUY  47.84 shares at $177.25 | Balance: $76323.61
# 774: SELL 160.67 shares at $180.09 | Balance: $105258.57
# 775: BUY  58.17 shares at $180.95 | Balance: $94732.71
# 776: SELL 58.17 shares at $179.58 | Balance: $105178.88
# 777: BUY  58.69 shares at $179.21 | Balance: $94660.98
# 778: SELL 58.69 shares at $177.82 | Balance: $105097.30
# 779: HOLD | Current price: $180.57 | Balance: $105097.30
# 780: BUY  58.08 shares at $180.96 | Balance: $94587.57
# 781: SELL 58.08 shares at $183.79 | Balance: $105261.66
# 782: BUY  57.42 shares at $183.31 | Balance: $94735.49
# 783: SELL 57.42 shares at $183.95 | Balance: $105298.41
# 784: HOLD | Current price: $186.01 | Balance: $105298.41
# 785: BUY  56.94 shares at $184.92 | Balance: $94768.56
# 786: BUY  51.22 shares at $185.01 | Balance: $85291.70
# 787: SELL 108.17 shares at $183.96 | Balance: $105189.95
# 788: BUY  56.25 shares at $187.00 | Balance: $94670.96
# 789: SELL 56.25 shares at $186.68 | Balance: $105171.95
# 790: HOLD | Current price: $185.27 | Balance: $105171.95
# 791: HOLD | Current price: $188.06 | Balance: $105171.95
# 792: BUY  55.57 shares at $189.25 | Balance: $94654.76
# 793: SELL 55.57 shares at $189.59 | Balance: $105190.84
# 794: HOLD | Current price: $193.97 | Balance: $105190.84
# 795: BUY  54.66 shares at $192.46 | Balance: $94671.76
# 796: BUY  49.48 shares at $191.33 | Balance: $85204.58
# 797: BUY  44.42 shares at $191.81 | Balance: $76684.12
# 798: SELL 148.56 shares at $190.68 | Balance: $105011.19
# 799: HOLD | Current price: $188.61 | Balance: $105011.19
# 800: HOLD | Current price: $188.08 | Balance: $105011.19
# 801: HOLD | Current price: $189.77 | Balance: $105011.19
# 802: BUY  55.11 shares at $190.54 | Balance: $94510.07
# 803: SELL 55.11 shares at $190.69 | Balance: $105019.45
# 804: HOLD | Current price: $193.99 | Balance: $105019.45
# 805: HOLD | Current price: $193.73 | Balance: $105019.45
# 806: HOLD | Current price: $195.10 | Balance: $105019.45
# 807: HOLD | Current price: $193.13 | Balance: $105019.45
# 808: BUY  54.71 shares at $191.94 | Balance: $94517.51
# 809: SELL 54.71 shares at $192.75 | Balance: $105063.77
# 810: BUY  54.26 shares at $193.62 | Balance: $94557.40
# 811: BUY  48.62 shares at $194.50 | Balance: $85101.66
# 812: BUY  44.04 shares at $193.22 | Balance: $76591.49
# 813: SELL 146.92 shares at $195.83 | Balance: $105363.31
# 814: HOLD | Current price: $196.45 | Balance: $105363.31
# 815: BUY  53.86 shares at $195.61 | Balance: $94826.98
# 816: SELL 53.86 shares at $192.58 | Balance: $105200.11
# 817: BUY  55.03 shares at $191.17 | Balance: $94680.10
# 818: SELL 55.03 shares at $181.99 | Balance: $104694.94
# 819: HOLD | Current price: $178.85 | Balance: $104694.94
# 820: BUY  58.23 shares at $179.80 | Balance: $94225.45
# 821: BUY  52.88 shares at $178.19 | Balance: $84802.90
# 822: SELL 111.11 shares at $177.97 | Balance: $104576.75
# 823: HOLD | Current price: $177.79 | Balance: $104576.75
# 824: HOLD | Current price: $179.46 | Balance: $104576.75
# 825: HOLD | Current price: $177.45 | Balance: $104576.75
# 826: HOLD | Current price: $176.57 | Balance: $104576.75
# 827: BUY  60.10 shares at $174.00 | Balance: $94119.08
# 828: SELL 60.10 shares at $174.49 | Balance: $104606.20
# 829: BUY  59.49 shares at $175.84 | Balance: $94145.59
# 830: SELL 59.49 shares at $177.23 | Balance: $104688.90
# 831: BUY  57.80 shares at $181.12 | Balance: $94220.01
# 832: BUY  53.42 shares at $176.38 | Balance: $84798.01
# 833: SELL 111.22 shares at $178.61 | Balance: $104662.94
# 834: HOLD | Current price: $180.19 | Balance: $104662.94
# 835: HOLD | Current price: $184.12 | Balance: $104662.94
# 836: HOLD | Current price: $187.65 | Balance: $104662.94
# 837: BUY  55.71 shares at $187.87 | Balance: $94196.64
# 838: SELL 55.71 shares at $189.46 | Balance: $104751.52
# 839: HOLD | Current price: $189.70 | Balance: $104751.52
# 840: HOLD | Current price: $182.91 | Balance: $104751.52
# 841: HOLD | Current price: $177.56 | Balance: $104751.52
# 842: BUY  58.79 shares at $178.18 | Balance: $94276.37
# 843: SELL 58.79 shares at $179.36 | Balance: $104820.89
# 844: HOLD | Current price: $176.30 | Balance: $104820.89
# 845: BUY  60.17 shares at $174.21 | Balance: $94338.80
# 846: BUY  53.68 shares at $175.74 | Balance: $84904.92
# 847: SELL 113.85 shares at $175.01 | Balance: $104829.84
# 848: BUY  58.90 shares at $177.97 | Balance: $94346.85
# 849: SELL 58.90 shares at $179.07 | Balance: $104894.62
# 850: HOLD | Current price: $175.49 | Balance: $104894.62
# 851: BUY  60.31 shares at $173.93 | Balance: $94405.16
# 852: SELL 60.31 shares at $174.79 | Balance: $104946.49
# 853: HOLD | Current price: $176.08 | Balance: $104946.49
# 854: BUY  61.03 shares at $171.96 | Balance: $94451.84
# 855: BUY  55.42 shares at $170.43 | Balance: $85006.66
# 856: SELL 116.45 shares at $170.69 | Balance: $104883.39
# 857: HOLD | Current price: $171.21 | Balance: $104883.39
# 858: HOLD | Current price: $173.75 | Balance: $104883.39
# 859: BUY  60.84 shares at $172.40 | Balance: $94395.05
# 860: SELL 60.84 shares at $173.66 | Balance: $104960.05
# 861: BUY  60.01 shares at $174.91 | Balance: $94464.04
# 862: SELL 60.01 shares at $177.49 | Balance: $105114.87
# 863: BUY  58.73 shares at $178.99 | Balance: $94603.38
# 864: BUY  53.03 shares at $178.39 | Balance: $85143.05
# 865: BUY  47.35 shares at $179.80 | Balance: $76628.74
# 866: BUY  42.40 shares at $180.71 | Balance: $68965.87
# 867: SELL 201.52 shares at $178.85 | Balance: $105007.19
# 868: HOLD | Current price: $178.72 | Balance: $105007.19
# 869: BUY  59.28 shares at $177.15 | Balance: $94506.47
# 870: SELL 59.28 shares at $175.84 | Balance: $104929.54
# 871: HOLD | Current price: $175.46 | Balance: $104929.54
# 872: BUY  60.70 shares at $172.88 | Balance: $94436.59
# 873: BUY  54.59 shares at $173.00 | Balance: $84992.93
# 874: SELL 115.28 shares at $173.44 | Balance: $104987.55
# 875: BUY  61.36 shares at $171.10 | Balance: $94488.79
# 876: SELL 61.36 shares at $166.89 | Balance: $104729.22
# 877: HOLD | Current price: $168.22 | Balance: $104729.22
# 878: BUY  61.50 shares at $170.29 | Balance: $94256.30
# 879: SELL 61.50 shares at $170.77 | Balance: $104758.74
# 880: BUY  60.22 shares at $173.97 | Balance: $94282.87
# 881: BUY  53.10 shares at $177.57 | Balance: $84854.58
# 882: BUY  48.04 shares at $176.65 | Balance: $76369.12
# 883: SELL 161.35 shares at $179.23 | Balance: $105287.55
# 884: HOLD | Current price: $181.82 | Balance: $105287.55
# 885: HOLD | Current price: $182.89 | Balance: $105287.55
# 886: HOLD | Current price: $182.41 | Balance: $105287.55
# 887: BUY  56.48 shares at $186.40 | Balance: $94758.79
# 888: SELL 56.48 shares at $184.80 | Balance: $105197.17
# 889: BUY  56.12 shares at $187.44 | Balance: $94677.45
# 890: SELL 56.12 shares at $188.01 | Balance: $105229.16
# 891: BUY  55.47 shares at $189.71 | Balance: $94706.24
# 892: BUY  49.93 shares at $189.69 | Balance: $85235.62
# 893: BUY  44.52 shares at $191.45 | Balance: $76712.05
# 894: BUY  40.24 shares at $190.64 | Balance: $69040.85
# 895: SELL 190.16 shares at $191.31 | Balance: $105419.52
# 896: BUY  55.49 shares at $189.97 | Balance: $94877.56
# 897: BUY  49.99 shares at $189.79 | Balance: $85389.80
# 898: SELL 105.48 shares at $190.40 | Balance: $105473.87
# 899: BUY  55.70 shares at $189.37 | Balance: $94926.48
# 900: SELL 55.70 shares at $189.95 | Balance: $105506.17
# 901: BUY  55.17 shares at $191.24 | Balance: $94955.55
# 902: SELL 55.17 shares at $189.43 | Balance: $105406.31
# 903: HOLD | Current price: $193.42 | Balance: $105406.31
# 904: BUY  54.81 shares at $192.32 | Balance: $94865.68
# 905: SELL 54.81 shares at $194.27 | Balance: $105513.19
# 906: HOLD | Current price: $195.71 | Balance: $105513.19
# 907: HOLD | Current price: $193.18 | Balance: $105513.19
# 908: HOLD | Current price: $194.71 | Balance: $105513.19
# 909: BUY  53.30 shares at $197.96 | Balance: $94961.87
# 910: BUY  47.93 shares at $198.11 | Balance: $85465.68
# 911: SELL 101.23 shares at $197.57 | Balance: $105466.52
# 912: BUY  53.84 shares at $195.89 | Balance: $94919.87
# 913: BUY  48.20 shares at $196.94 | Balance: $85427.88
# 914: SELL 102.04 shares at $194.83 | Balance: $105307.76
# 915: HOLD | Current price: $194.68 | Balance: $105307.76
# 916: HOLD | Current price: $193.60 | Balance: $105307.76
# 917: HOLD | Current price: $193.05 | Balance: $105307.76
# 918: BUY  54.52 shares at $193.15 | Balance: $94776.98
# 919: SELL 54.52 shares at $193.58 | Balance: $105331.20
# 920: BUY  54.71 shares at $192.53 | Balance: $94798.09
# 921: SELL 54.71 shares at $185.64 | Balance: $104954.26
# 922: HOLD | Current price: $184.25 | Balance: $104954.26
# 923: BUY  57.70 shares at $181.91 | Balance: $94458.83
# 924: SELL 57.70 shares at $181.18 | Balance: $104912.13
# 925: HOLD | Current price: $185.56 | Balance: $104912.13
# 926: BUY  56.67 shares at $185.14 | Balance: $94420.92
# 927: SELL 56.67 shares at $186.19 | Balance: $104971.63
# 928: BUY  56.56 shares at $185.59 | Balance: $94474.47
# 929: BUY  50.81 shares at $185.92 | Balance: $85027.02
# 930: BUY  46.30 shares at $183.63 | Balance: $76524.32
# 931: SELL 153.68 shares at $182.68 | Balance: $104598.41
# 932: HOLD | Current price: $188.63 | Balance: $104598.41
# 933: BUY  54.60 shares at $191.56 | Balance: $94138.57
# 934: BUY  48.55 shares at $193.89 | Balance: $84724.71
# 935: SELL 103.16 shares at $195.18 | Balance: $104858.70
# 936: HOLD | Current price: $194.50 | Balance: $104858.70
# 937: BUY  54.00 shares at $194.17 | Balance: $94372.84
# 938: SELL 54.00 shares at $192.42 | Balance: $104764.20
# 939: BUY  54.64 shares at $191.73 | Balance: $94287.78
# 940: SELL 54.64 shares at $188.04 | Balance: $104562.58
# 941: HOLD | Current price: $184.40 | Balance: $104562.58
# 942: HOLD | Current price: $186.86 | Balance: $104562.58
# 943: HOLD | Current price: $185.85 | Balance: $104562.58
# 944: HOLD | Current price: $187.68 | Balance: $104562.58
# 945: HOLD | Current price: $189.30 | Balance: $104562.58
# 946: HOLD | Current price: $189.41 | Balance: $104562.58
# 947: HOLD | Current price: $188.32 | Balance: $104562.58
# 948: HOLD | Current price: $188.85 | Balance: $104562.58
# 949: BUY  55.87 shares at $187.15 | Balance: $94106.32
# 950: SELL 55.87 shares at $185.04 | Balance: $104444.69
# 951: HOLD | Current price: $184.15 | Balance: $104444.69
# 952: BUY  56.81 shares at $183.86 | Balance: $94000.22
# 953: SELL 56.81 shares at $182.31 | Balance: $104356.64
# 954: BUY  57.48 shares at $181.56 | Balance: $93920.98
# 955: BUY  51.51 shares at $182.32 | Balance: $84528.88
# 956: SELL 108.99 shares at $184.37 | Balance: $104623.75
# 957: BUY  57.32 shares at $182.52 | Balance: $94161.38
# 958: SELL 57.32 shares at $181.16 | Balance: $104545.80
# 959: BUY  57.24 shares at $182.63 | Balance: $94091.22
# 960: BUY  51.86 shares at $181.42 | Balance: $84682.09
# 961: BUY  46.85 shares at $180.75 | Balance: $76213.88
# 962: SELL 155.96 shares at $179.66 | Balance: $104233.43
# 963: HOLD | Current price: $175.10 | Balance: $104233.43
# 964: HOLD | Current price: $170.12 | Balance: $104233.43
# 965: BUY  61.63 shares at $169.12 | Balance: $93810.09
# 966: BUY  55.51 shares at $169.00 | Balance: $84429.08
# 967: SELL 117.14 shares at $170.73 | Balance: $104428.69
# 968: HOLD | Current price: $172.75 | Balance: $104428.69
# 969: BUY  60.28 shares at $173.23 | Balance: $93985.82
# 970: BUY  54.92 shares at $171.13 | Balance: $84587.23
# 971: SELL 115.20 shares at $173.00 | Balance: $104517.52
# 972: BUY  60.55 shares at $172.62 | Balance: $94065.77
# 973: BUY  54.15 shares at $173.72 | Balance: $84659.20
# 974: BUY  48.08 shares at $176.08 | Balance: $76193.27
# 975: SELL 162.78 shares at $178.67 | Balance: $105276.40
# 976: HOLD | Current price: $171.37 | Balance: $105276.40
# 977: BUY  61.11 shares at $172.28 | Balance: $94748.76
# 978: BUY  55.46 shares at $170.85 | Balance: $85273.88
# 979: SELL 116.57 shares at $169.71 | Balance: $105056.13
# 980: BUY  60.62 shares at $173.31 | Balance: $94550.52
# 981: SELL 60.62 shares at $171.48 | Balance: $104945.20
# 982: HOLD | Current price: $170.03 | Balance: $104945.20
# 983: HOLD | Current price: $168.84 | Balance: $104945.20
# 984: BUY  61.86 shares at $169.65 | Balance: $94450.68
# 985: BUY  55.95 shares at $168.82 | Balance: $85005.61
# 986: SELL 117.81 shares at $169.58 | Balance: $104983.39
# 987: BUY  62.32 shares at $168.45 | Balance: $94485.05
# 988: BUY  55.69 shares at $169.67 | Balance: $85036.55
# 989: SELL 118.01 shares at $167.78 | Balance: $104836.39
# 990: HOLD | Current price: $175.04 | Balance: $104836.39
# 991: HOLD | Current price: $176.55 | Balance: $104836.39
# 992: HOLD | Current price: $172.69 | Balance: $104836.39
# 993: BUY  61.89 shares at $169.38 | Balance: $94352.75
# 994: SELL 61.89 shares at $168.00 | Balance: $104750.98
# 995: HOLD | Current price: $167.04 | Balance: $104750.98
# 996: BUY  63.49 shares at $165.00 | Balance: $94275.88
# 997: SELL 63.49 shares at $165.84 | Balance: $104804.30
# 998: HOLD | Current price: $166.90 | Balance: $104804.30
# 999: HOLD | Current price: $169.02 | Balance: $104804.30
# 1000: HOLD | Current price: $169.89 | Balance: $104804.30
# 1001: HOLD | Current price: $169.30 | Balance: $104804.30
# 1002: BUY  60.41 shares at $173.50 | Balance: $94323.87
# 1003: BUY  55.38 shares at $170.33 | Balance: $84891.48
# 1004: BUY  50.14 shares at $169.30 | Balance: $76402.34
# 1005: SELL 165.93 shares at $173.03 | Balance: $105112.46
# 1006: HOLD | Current price: $183.38 | Balance: $105112.46
# 1007: HOLD | Current price: $181.71 | Balance: $105112.46
# 1008: HOLD | Current price: $182.40 | Balance: $105112.46
# 1009: BUY  57.52 shares at $182.74 | Balance: $94601.22
# 1010: BUY  51.25 shares at $184.57 | Balance: $85141.09
# 1011: BUY  46.51 shares at $183.05 | Balance: $76626.98
# 1012: SELL 155.29 shares at $186.28 | Balance: $105553.96
# 1013: HOLD | Current price: $187.43 | Balance: $105553.96
# 1014: BUY  55.64 shares at $189.72 | Balance: $94998.56
# 1015: SELL 55.64 shares at $189.84 | Balance: $105560.63
# 1016: BUY  55.60 shares at $189.87 | Balance: $95004.57
# 1017: SELL 55.60 shares at $191.04 | Balance: $105625.68
# 1018: BUY  54.91 shares at $192.35 | Balance: $95063.11
# 1019: SELL 54.91 shares at $190.90 | Balance: $105546.05
# 1020: BUY  56.48 shares at $186.88 | Balance: $94991.45
# 1021: SELL 56.48 shares at $189.98 | Balance: $105721.14
# 1022: HOLD | Current price: $189.99 | Balance: $105721.14
# 1023: BUY  55.56 shares at $190.29 | Balance: $95149.02
# 1024: BUY  49.74 shares at $191.29 | Balance: $85634.12
# 1025: BUY  44.54 shares at $192.25 | Balance: $77070.71
# 1026: SELL 149.84 shares at $194.03 | Balance: $106144.50
# 1027: BUY  54.62 shares at $194.35 | Balance: $95530.05
# 1028: BUY  48.77 shares at $195.87 | Balance: $85977.04
# 1029: BUY  44.21 shares at $194.48 | Balance: $77379.34
# 1030: SELL 147.60 shares at $196.89 | Balance: $106439.51
# 1031: BUY  55.12 shares at $193.12 | Balance: $95795.55
# 1032: SELL 55.12 shares at $207.15 | Balance: $107212.78
# 1033: HOLD | Current price: $213.07 | Balance: $107212.78
# 1034: BUY  50.04 shares at $214.24 | Balance: $96491.50
# 1035: SELL 50.04 shares at $212.49 | Balance: $107125.20
# 1036: HOLD | Current price: $216.67 | Balance: $107125.20
# 1037: HOLD | Current price: $214.29 | Balance: $107125.20
# 1038: HOLD | Current price: $209.68 | Balance: $107125.20
# 1039: BUY  51.63 shares at $207.49 | Balance: $96412.68
# 1040: SELL 51.63 shares at $208.14 | Balance: $107158.76
# 1041: HOLD | Current price: $209.07 | Balance: $107158.76
# 1042: HOLD | Current price: $213.25 | Balance: $107158.76
# 1043: HOLD | Current price: $214.10 | Balance: $107158.76
# 1044: HOLD | Current price: $210.62 | Balance: $107158.76
# 1045: BUY  49.44 shares at $216.75 | Balance: $96442.88
# 1046: BUY  43.78 shares at $220.27 | Balance: $86798.59
# 1047: SELL 93.22 shares at $221.55 | Balance: $107452.11
# 1048: HOLD | Current price: $226.34 | Balance: $107452.11
# Action stats: {<Actions.Sell: 0>: 619, <Actions.Buy: 1>: 430}
# Final Balance: $107452.11

# %%
# Create your two charts below. Note, do not change the fig and ax variable names.

# Create a price chart showing buy/sell actions
fig, ax = plt.subplots()
env.unwrapped.render_all()
ax.set_title("PPO Agent - Trading Actions")
plt.show()

# Create a chart showing cash balance over time
fig2, ax2 = plt.subplots()
ax2.plot(balance_history)
ax2.set_title("PPO Agent - Balance over time")
ax2.set_xlabel("Steps")
ax2.set_ylabel("Balance ($)")

fig2.tight_layout()
plt.show()

# %% [markdown]
# Questions/Answers
# - What do you think about the performance of this model?
# The model has technically been profitable in that the cash balance is higher than what it started with. However, it is very hard to not be profitable given the extreme increase in the price of AAPL over the 15 years of data provided. You would have made significantly more by simply spending all of the initial balance on shares at the starting date, holding the shares, and selling at the ending date. You likely would have made significantly more over that time period by investing your initial balance in any number of asset classes.
#
# - Why do you think it has performed the way it has?
# Every transaction that this model makes is the same size. That is why your balance history will have a lot of spikes and drops, as the model buys with 10% of its balance and then sells again instantly with 10% of its balance, making either a small profit or loss. An improvement that could be made here is calculating the position size based on the confidence the model has in its decision, taking a smaller position if less confident and a larger position if more confident. This model also does not account for any transaction costs or slippage which would be a key factor in a real trading scenario.
#
# - How could the data we have selected impact the performance of the model?
# This model uses 15 years of data which is a long time. It is very hard to not make money given a stock that has gone from around $4 to over $200! An interesting experiment would be to select some stock data for a company that has not seen the same extreme growth that Apple has seen and observe how the model performs.
